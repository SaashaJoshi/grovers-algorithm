# %%
from qiskit import *
from qiskit.visualization import *
from math import pi, sqrt
import numpy as np

# %%
def grover_operator(circuit, n, target_binary):
    # Grover's Oracle
    oracle_gate = grover_oracle(n, target_binary)
    circuit.append(oracle_gate, range(n+1))
    
    circuit.h(range(n+1))
        
    # Amplifier
    amplification_gate = amplification(n)
    circuit.append(amplification_gate, range(n))

    circuit.h(range(n))

# %%
def grover_oracle(n, target_binary):
    circuit = QuantumCircuit(n+1)
    
    # Grover's Oracle
    for index, value in reversed(list(enumerate(target_binary))):  
        if value == '0':
            circuit.x(n-1-index)    
            # Adding X gate to the qubit with |0> value. Also the order of qubits is reversed in Qiskit.
       
    control_qubits = [0, 1, 2, 3]
    circuit.mct(control_qubits, n, n)

    for index, value in enumerate(target_binary):  
        if value == '0':
            circuit.x(n-1-index)  
    
    oracle_gate = circuit.to_gate()
    oracle_gate.name = 'Oracle'
    
    return oracle_gate

# %%
def amplification(n):
    circuit = QuantumCircuit(n)
    
    circuit.x(range(n))
    
    # Amplifier
    # V
    circuit.cu1(pi/4, 0, 3)

    # V-dagger
    circuit.cx(0, 1)
    circuit.cu1(-pi/4, 1, 3)
    circuit.cx(0, 1)

    # V
    circuit.cu1(pi/4, 1, 3)

    # V-dagger
    circuit.cx(1, 2)
    circuit.cu1(-pi/4, 2, 3)

    # V
    circuit.cx(0, 2)
    circuit.cu1(pi/4, 2, 3)

    # V-dagger
    circuit.cx(1, 2)
    circuit.cu1(-pi/4, 2, 3)

    # V
    circuit.cx(0, 2)
    circuit.cu1(pi/4, 2, 3)
    
    circuit.x(range(n))

    amplification_gate = circuit.to_gate()
    amplification_gate.name = 'Amplification'
    
    return amplification_gate

# %%
def initialize(circuit, n):
    # circuit.reset(range(n+1))
    circuit.x(n)
    circuit.barrier()

    circuit.h(range(n+1))
    circuit.barrier()

# %%
def get_target(n):
    # Target qubit combination  
    target = int(input('Enter the target number (from 0 to 15): '))
#     max_n = 2**n
#     target = np.random.randint(max_n)
    print('Target number: ', target)

    # Target Binary
    target_binary = "{0:04b}".format(target)
    print('Target binary: ', target_binary)
    
    return target, target_binary

# %%
def main():
    # Qubits
    n = 4     # n = int(input('Enter number of required qubits: '))
    print('Number of qubits: ', n)
    
    # Target
    target, target_binary = get_target(n)
    
    # Initialize  
    circuit = QuantumCircuit(n+1, n)    # Add one for ancillia qubit
    initialize(circuit, n)  
    
    # Grover's Operator
    grover_operator(circuit, n, target_binary)
    grover_operator(circuit, n, target_binary)
#     grover_operator(circuit, n, target_binary)
    
    # End
    circuit.barrier()
    circuit.measure(range(n), range(n))
    
    # circuit.draw('mpl')
    return circuit

# %%
circuit = main()
circuit.draw('mpl')
# Out:
# Number of qubits:  4
# Enter the target number (from 0 to 15): 12
# Target number:  12
# Target binary:  1100

# %%
backend = Aer.get_backend('qasm_simulator')
results = execute(circuit, backend, shots = 1024).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0000': 36, '0001': 24, '0010': 30, '0011': 31, '0100': 41, '0101': 36, '0110': 36, '0111': 28, '1000': 38, '1001': 40, '1010': 35, '1011': 32, '1100': 515, '1101': 33, '1110': 36, '1111': 33}

# %%
from qiskit import IBMQ
from qiskit.tools.monitor import job_monitor

provider = IBMQ.load_account()
# backend = provider.backends(simulator = False)
qcomp = provider.get_backend('ibmq_qasm_simulator')
job2 = execute(circuit, qcomp, shots = 1024)
job_monitor(job2)
# Out:
# /home/saasha/anaconda3/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# ibmqfactory.load_account:WARNING:2021-01-31 22:59:45,938: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run

# %%
result = job2.result()
counts = result.get_counts(circuit)
print(counts)
plot_histogram(counts)
# Out:
# {'0000': 36, '0001': 36, '0010': 32, '0011': 36, '0100': 36, '0101': 33, '0110': 44, '0111': 28, '1000': 40, '1001': 42, '1010': 31, '1011': 35, '1100': 487, '1101': 40, '1110': 30, '1111': 38}

# %%
time_steps = job2.time_per_step()
print(f'RUNNING: {time_steps["RUNNING"]}')
print(f'COMPLETED: {time_steps["COMPLETED"]}')

RUNTIME = time_steps["COMPLETED"] - time_steps["RUNNING"]
print(f'RUNTIME: {RUNTIME.total_seconds()}')
# Out:
# RUNNING: 2021-01-31 22:59:56.623000+05:30
# COMPLETED: 2021-01-31 22:59:57.975000+05:30
# RUNTIME: 1.352

# %%
### from qiskit.providers.ibmq import least_busy
from qiskit import IBMQ
from qiskit.tools.monitor import job_monitor

provider = IBMQ.load_account()
backend = provider.backends(simulator = False)
qcomp = provider.get_backend('ibmq_santiago')
job = execute(circuit, qcomp, shots = 1024)
job_monitor(job)
# Out:
# ibmqfactory.load_account:WARNING:2021-01-31 23:00:07,590: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run

# %%
result = job.result()
counts = result.get_counts(circuit)
print(counts)
plot_histogram(counts)
# Out:
# {'0000': 59, '0001': 68, '0010': 88, '0011': 84, '0100': 58, '0101': 48, '0110': 56, '0111': 58, '1000': 51, '1001': 69, '1010': 71, '1011': 77, '1100': 49, '1101': 41, '1110': 75, '1111': 72}

# %%
time_steps = job.time_per_step()
print(f'RUNNING: {time_steps["RUNNING"]}')
print(f'COMPLETED: {time_steps["COMPLETED"]}')

RUNTIME = time_steps["COMPLETED"] - time_steps["RUNNING"]
print(f'RUNTIME: {RUNTIME.total_seconds()}')
# Out:
# RUNNING: 2021-01-31 23:53:24.839000+05:30
# COMPLETED: 2021-01-31 23:53:39.258000+05:30
# RUNTIME: 14.419
